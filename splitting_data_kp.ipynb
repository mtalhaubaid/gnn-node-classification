# %%
import pandas as pd
df=pd.read_csv('user_nodes_data.csv')

# %%
df
# Out:
#         UserId  CurrentProficiency  PreviousProficiency  CurrentAccuracy  \
# 0         2881                   1                  1.0         36.36364
# 1         2903                   4                  4.0        100.00000
# 2         2909                   3                  NaN        100.00000
# 3         2909                   2                  NaN        100.00000
# 4         2903                   4                  4.0        100.00000
# ...        ...                 ...                  ...              ...
# 120703  439664                   1                  NaN         50.00000
# 120704  439664                   1                  4.0         50.00000
# 120705  439664                   1                  NaN          0.00000
# 120706   50174                   1                  NaN          0.00000
# 120707   50174                   1                  NaN          0.00000
#
#         PreviousAccuracy  CoveragePercentage  AccuracyPercentage  \
# ...

# %%
len(df.SkillId)
# Out:
# 120708

# %%
df.SkillId.unique()
# Out:
# array([ 433,  432,  448,  450,  514,  431,  434,  449,  513,  438,  445,
#         461,  479,  512,  437,  453,  460,  515,  467,  516,  464,  465,
#         435,  521,  480,  471,  481,  440,  441,  473,  476,  442,  459,
#         526,  475,  439,  523,  457,  525,  487,  485,  443,  486,  472,
#         446,  478,  462,  444,  455,  469,  447,  454,  520,  470,  436,
#         452,  463,  522,  468,  527,  488,  477,  451,  482,  483,  456,
#         524,  474,  974,  941,  975,  715, 2021,  944,  518,  466,  484,
#        2022,  717,  719, 2016, 2025,  725,  991, 2012, 2013, 2028,  864,
#         962,  978,  989, 2023, 2018,  942,  960, 2027,  712,  980,  721,
#         726,  943,  976, 2010, 2011, 2030,  961,  988, 2015,  965,  868,
#         867, 2020,  718,  866,  985,  969, 2007,  968,  720, 2006,  963,
#         727,  870,  990,  970,  972, 2024,  713,  979, 2008, 2026,  865,
#         983,  986, 2005,  716,  982, 2019,  966,  967,  517,  984,  869,
# ...

# %%
df.SkillId.describe()
# Out:
# count    120708.000000
# mean        626.299326
# std         393.534337
# min         431.000000
# 25%         441.000000
# 50%         475.000000
# 75%         714.000000
# max        3687.000000
# Name: SkillId, dtype: float64

# %%
df.loc[df['SkillId'] == 433]
# Out:
#         UserId  CurrentProficiency  PreviousProficiency  CurrentAccuracy  \
# 0         2881                   1                  1.0         36.36364
# 3         2909                   2                  NaN        100.00000
# 4         2903                   4                  4.0        100.00000
# 6         2939                   4                  2.0         81.81818
# 12        2971                   4                  4.0        100.00000
# ...        ...                 ...                  ...              ...
# 119467  437790                   1                  NaN          0.00000
# 119481  437792                   1                  NaN          0.00000
# 119488   50174                   1                  NaN          0.00000
# 119491  437858                   1                  NaN          0.00000
# 119494  437816                   1                  NaN          0.00000
#
#         PreviousAccuracy  CoveragePercentage  AccuracyPercentage  \
# ...

# %%
len(df.SkillId)
# Out:
# 120708

# %%
df.groupby

# %%
for i in range(len(df.SkillId)):
    df.loc[df['SkillId'] == ]
